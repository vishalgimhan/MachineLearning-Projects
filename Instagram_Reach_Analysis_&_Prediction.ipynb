# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalgimhan/MachineLearning-Projects/blob/main/Instagram_Reach_Analysis_%26_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

#!pip install wordcloud

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor

# %%
#Load dataset
data = pd.read_csv("/content/drive/MyDrive/Datasets/Instagram.csv", encoding='latin1')
print(data.head())
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
#Check for null values
data.isnull().sum()
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
#data = data.dropna()

# %%
#Data Types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %% [markdown]
# #Analyze Reach

# %%
#Impressions from Home
plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title('Distribution of Impressions from Home')
sns.distplot(data['From Home'])
plt.show()
# Out:
# <ipython-input-11-40a8f2b2936c>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# Impressions range around 1500 to 4000 From Home

# %%
#Impressions from Hashtags
plt.figure(figsize=(10, 8))
plt.title('Distribution of Impressions from Hashtags')
sns.distplot(data['From Hashtags'])
plt.show()
# Out:
# <ipython-input-12-e98975ed9de1>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
#Impressions from Explore
plt.figure(figsize=(10, 8))
plt.title('Distribution of Impressions from Explore')
sns.distplot(data['From Explore'])
plt.show()
# Out:
# <ipython-input-13-a3974e7c3a06>:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# So less recommendation by Instgram for the posts.
# Though some posts have good impressions, its low compared to Hashtags

# %%
home = data["From Home"].sum()
hashtags = data["From Hashtags"].sum()
explore = data["From Explore"].sum()
other = data["From Other"].sum()

labels = ['From Home', 'From Hashtags', 'From Explore', 'Other']
values = [home, hashtags, explore, other]

fig = px.pie(data, values=values, names=labels, title='Impressions on Instagram Posts from Various Sources', hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Analyze Content

# %%
#Word Cloud with Captions
text = " ".join(i for i in data.Caption)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.style.use('classic')
plt.figure(figsize=(12, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Most used hashtags
text = " ".join(i for i in data.Hashtags)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure(figsize=(12, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Analyze relationships to find most important factors of the Reach

#Likes and Impressions
figure = px.scatter(data_frame=data, x="Impressions",
                    y="Likes", size="Likes", trendline="ols",
                    title="Relationship between Likes and Impressions")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# there is a linear relationship

# %%
#Comments and Impressions
figure = px.scatter(data_frame=data, x="Impressions",
                    y="Comments", size="Comments", trendline="ols",
                    title="Relationship between Comments and Impressions")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# looks like comments doesnt affect Impressions

# %%
#Shares and Impressions
figure = px.scatter(data_frame=data, x="Impressions",
                    y="Shares", size="Shares", trendline="ols",
                    title="Relationship between Shares and Impressions")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# there is a positive relationship, but not as high as Likes

# %%
#Shares and Impressions
figure = px.scatter(data_frame=data, x="Impressions",
                    y="Saves", size="Saves", trendline="ols",
                    title="Relationship between Saves and Impressions")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# linear relationship between saves and impressions

# %%
#Correlation with Impressions

#consider only numerical columns
data2 = data.copy()
data2.drop(["Caption", "Hashtags"], axis=1, inplace=True)

correlation = data2.corr()
print(correlation["Impressions"].sort_values(ascending=False))
# Out:
# Impressions       1.000000
# From Explore      0.893607
# Follows           0.889363
# Likes             0.849835
# From Home         0.844698
# Saves             0.779231
# Profile Visits    0.760981
# Shares            0.634675
# From Other        0.592960
# From Hashtags     0.560760
# Comments         -0.028524
# Name: Impressions, dtype: float64

# %% [markdown]
# So more likes and shares,more reach
# high shares will help get more reach, but low shares doesnt mean low reach

# %% [markdown]
# #Analyze Conversion Rate
#
# (Follows/Profile Visits) * 100

# %%
conversion_rate = (data["Follows"].sum() / data["Profile Visits"].sum()) * 100
print(conversion_rate)
# Out:
# 41.00265604249668

# %%
#Followers gained from Profile Visits
figure = px.scatter(data_frame=data, x="Profile Visits",
                    y="Follows", size="Follows", trendline="ols",
                    title="Relationship between Profile Visits and Followers gained")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# linear relationship

# %% [markdown]
# #Intagram Reach Prediction Model

# %%
x = np.array(data[["Likes", "Saves", "Comments", "Shares", "Profile Visits", "Follows"]])
y = np.array(data["Impressions"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y,
                                                test_size=0.2,
                                                random_state=42)

# %%
model = PassiveAggressiveRegressor()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.8720056797753497

# %%
#Make Predictions

#features = [["Likes", "Saves", "Comments", "Shares", "Profile Visits", "Follows"]]
features = np.array([[282.0, 233.0, 4.0, 9.0, 165.0, 54.0]])
model.predict(features)
# Out:
# array([13391.52562434])
